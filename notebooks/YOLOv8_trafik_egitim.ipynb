# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 34.3 MB/s eta 0:00:00
# ...

# %%
# 1. Klasör yapısını temizle ve v5 için yeni klasör oluştur
# %cd /content/
# !rm -rf dataset_v5
# !mkdir dataset_v5

# 2. Drive'daki v5 zip dosyasını Colab lokal hafızasına kopyala
# !cp /content/drive/MyDrive/trafik_dataset_v5.zip /content/

# 3. Zip dosyasını -o parametresiyle otomatik olarak üzerine yazarak aç (Soru sormaz)
# !unzip -q -o /content/trafik_dataset_v5.zip -d /content/dataset_v5/

# 4. Kalabalık etmemesi için kopyalanan zip dosyasını lokalden sil
# !rm /content/trafik_dataset_v5.zip

print("Version 5 veri seti başarıyla ve takılmadan Colab lokaline açıldı!")
# Out:
# /content
# Version 5 veri seti başarıyla ve takılmadan Colab lokaline açıldı!

# %%
import yaml

yaml_path = '/content/dataset_v5/data.yaml'

with open(yaml_path, 'r') as f:
    data = yaml.safe_load(f)

# Yolları kesin olarak v5 klasörüne yönlendiriyoruz
data['path'] = '/content/dataset_v5'
data['train'] = 'train/images'
data['val'] = 'valid/images'

# Eğer yaml içinde test satırı kalmışsa hata vermemesi için siliyoruz
if 'test' in data:
    del data['test']

with open(yaml_path, 'w') as f:
    yaml.dump(data, f)

print("data.yaml yolları v5 için kusursuz hale getirildi!")
print("Güncel v5 İçeriği:\n", data)
# Out:
# data.yaml yolları v5 için kusursuz hale getirildi!
# Güncel v5 İçeriği:
#  {'train': 'train/images', 'val': 'valid/images', 'nc': 30, 'names': ['U-donusu-yasak', 'ada-etrafinda-don', 'anayol-tali-yol-kavsak', 'dikkat', 'donel-kavsak', 'dur', 'durmak-yasak', 'giris-yasak', 'hiz-siniri-30', 'iki-yonlu-trafik', 'ileri-ve-saga-mecburi-yol', 'ileri-ve-sola-mecburi-yol', 'kasisli-yol', 'kaygan-yol', 'kirmizi-isik', 'park-yasak', 'park-yeri', 'saga-donulmez', 'saga-tehlikeli-viraj', 'sagdan-gidin', 'sola-donulmez', 'sola-tehlikeli-viraj', 'sollamak-yasak', 'tehlikeli-devamli-virajlar', 'tek-yon', 'trafik-isigi-uyari', 'yaya-gecidi-bilgi', 'yaya-gecidi-uyari', 'yesil-isik', 'yol-ver'], 'roboflow': {'workspace': 'ulas-tthvj', 'project': 'traffic-signs-and-traffic-lights-kt7qh', 'version': 5, 'license': 'CC BY 4.0', 'url': 'https://universe.roboflow.com/ulas-tthvj/traffic-signs-and-traffic-lights-kt7qh/dataset/5'}, 'path': '/content/dataset_v5'}

# %%
from ultralytics import YOLO

# 1. Sıfır model yerine, Drive'daki 24 epoch eğitilmiş last.pt dosyasını alıyoruz.
model = YOLO('/content/drive/MyDrive/YOLOv8_Trafik_Projesi/edirne_modeli_v5/weights/last.pt')

# 2. Motoru 1'den değil, kaldığı yerden (25. epoch'tan) devam ediyoruz.
model.train(resume=True)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.4.51 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...
